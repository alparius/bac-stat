# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import geoplot as gplt

# from sklearn.linear_model import Lasso, Ridge
# from sklearn.linear_model import LinearRegression
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import cross_val_score
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e5e6ec1e8dc9> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import geopandas as gpd
#       5 import geoplot as gplt
#       6
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
results_2019 = pd.read_csv("../data/bac-results-2019.csv", index_col=0)
results_2020 = pd.read_csv("../data/bac-results-2020.csv", index_col=0)
results_2021 = pd.read_csv("../data/bac-results-2021.csv", index_col=0)
results_2019.fillna('', inplace=True)
results_2020.fillna('', inplace=True)
results_2021.fillna('', inplace=True)
print()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option('display.max_columns', None)
display(results_2021.head())
print(results_2021.columns)
# Out:
#           id  county_rank  country_rank  \
# 0  AB1000328         1866         95288
# 1  AB1005434         1867         95289
# 2  AB1007560         1728         87156
# 3  AB1007648         1868         95290
# 4  AB1008259         1767         89406
#
#                                          high_school county prev_promotion  \
# 0                COLEGIUL TEHNIC "APULUM" ALBA IULIA     AB             DA
# 1   LICEUL TEOLOGIC ROMANO-CATOLIC "GROF MAJLATH ...     AB             DA
# 2           LICEUL "DR. LAZAR CHIRILA" BAIA DE ARIES     AB             DA
# 3           LICEUL "DR. LAZAR CHIRILA" BAIA DE ARIES     AB             DA
# 4           LICEUL "DR. LAZAR CHIRILA" BAIA DE ARIES     AB             DA
#
#   school_type                  specialization      romanian_competency  \
# 0          ZI  TEHNICIAN DESIGNER VESTIMENTAR   Utilizator nivel mediu
# 1          ZI        TEOLOGIE ROMANO-CATOLICA   Utilizator nivel mediu
# 2          ZI          MATEMATICA-INFORMATICA  Utilizator experimentat
# 3          ZI          MATEMATICA-INFORMATICA  Utilizator experimentat
# 4          ZI          MATEMATICA-INFORMATICA  Utilizator experimentat
#
#    romanian_written romanian_written_appeal  romanian_written_final  \
# 0              5.05                                            5.05
# 1              3.70                    4.45                    4.45
# 2              6.05                                            6.05
# 3              6.15                                            6.15
# 4              5.50                                            5.50
#
#            mother_tongue mother_tongue_competency mother_tongue_written  \
# 0
# 1  LIMBA MAGHIARA (REAL)       Utilizator avansat                  7.55
# 2
# 3
# 4
#
#   mother_tongue_written_appeal mother_tongue_written_final modern_language  \
# 0                                                            LIMBA ENGLEZA
# 1                                                     7.55   LIMBA ENGLEZA
# 2                                                            LIMBA ENGLEZA
# 3                                                            LIMBA ENGLEZA
# 4                                                            LIMBA ENGLEZA
#
#   modern_language_results     mandatory_subject  mandatory_subject_written  \
# 0          A2-A2-A2-A2-A2       MATEMATICA TEHN                       2.95
# 1          B1-B1-B1-B1-B1               ISTORIE                       9.35
# 2          B2-B2-B2-B2-B2  MATEMATICA MATE-INFO                       5.35
# 3          B1-B1-B1-B1-B1  MATEMATICA MATE-INFO                       3.80
# 4          A2-A2-A2-A2-A2  MATEMATICA MATE-INFO                       5.80
#
#   mandatory_subject_written_appeal  mandatory_subject_written_final  \
# 0                                                              2.95
# 1                                                              9.35
# 2                                                              5.35
# 3                              3.2                             3.20
# 4                                                              5.80
#
#                                     elective_subject  \
# 0                       BIOLOGIE VEGETALA SI ANIMALA
# 1                                          FILOSOFIE
# 2   ANATOMIE SI FIZIOLOGIE UMANA, GENETICA SI ECO...
# 3   ANATOMIE SI FIZIOLOGIE UMANA, GENETICA SI ECO...
# 4                                         FIZICA TEO
#
#    elective_subject_written elective_subject_written_appeal  \
# 0                      7.80
# 1                      7.30
# 2                      6.75
# 3                      5.75
# 4                      6.55                             6.4
#
#    elective_subject_written_final     digital_competencies final_grade  \
# 0                            7.80       Utilizator avansat
# 1                            7.30  Utilizator experimentat
# 2                            6.75  Utilizator experimentat        6.05
# 3                            5.75  Utilizator experimentat
# 4                            6.40  Utilizator experimentat         5.9
#
#   successful
# 0    RESPINS
# 1    RESPINS
# 2     REUSIT
# 3    RESPINS
# 4    RESPINS
# Index(['id', 'county_rank', 'country_rank', 'high_school', 'county',
#        'prev_promotion', 'school_type', 'specialization',
#        'romanian_competency', 'romanian_written', 'romanian_written_appeal',
#        'romanian_written_final', 'mother_tongue', 'mother_tongue_competency',
#        'mother_tongue_written', 'mother_tongue_written_appeal',
#        'mother_tongue_written_final', 'modern_language',
#        'modern_language_results', 'mandatory_subject',
#        'mandatory_subject_written', 'mandatory_subject_written_appeal',
#        'mandatory_subject_written_final', 'elective_subject',
#        'elective_subject_written', 'elective_subject_written_appeal',
#        'elective_subject_written_final', 'digital_competencies', 'final_grade',
#        'successful'],
#       dtype='object')

# %%
# Plot the distribution of the Romanian exam grades.

romanian_only_results = results_2021[(results_2021['mother_tongue'] == '') & (results_2021['romanian_written_final'] > -1)]
romanian_plus_results = results_2021[(results_2021['mother_tongue'] != '') & (results_2021['romanian_written_final'] > -1)]

plt.hist(romanian_only_results['romanian_written_final'].to_list(), bins=18, density=True, alpha = 0.3, color='purple', edgecolor='black', linewidth=1, histtype= "stepfilled")
plt.hist(romanian_plus_results['romanian_written_final'].to_list(), bins=18, density=True, alpha = 0.3, color='orange', edgecolor='black', linewidth=1, histtype= "stepfilled")
plt.legend(["Romanians'", "Minorities'"])
plt.show()
